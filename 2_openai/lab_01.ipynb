# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name='Jokester', instructions='You are a jokester. Tell a joke.', model='gpt-4o-mini')

# %%
agent
# Out:
# Agent(name='Jokester', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a jokester. Tell a joke.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
result = await Runner.run(agent, "Tell a joke about autonomous agents.")
# Out:
# /var/folders/6j/br0rgly562qd_3yf34bvpxl40000gn/T/ipykernel_43332/2608863413.py:1: RuntimeWarning: coroutine 'Runner.run' was never awaited
#   result = await Runner.run(agent, "Tell a joke about autonomous agents.")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
print(result.final_output)
# Out:
# Why did the autonomous agent break up with its robot partner?
#
# It just needed a little more "space" to process its feelings!

# %%
with trace('tell us joke'):
    result = await Runner.run(agent, "Tell a joke about autonomous agents.")
    print(result.final_output)
# Out:
# Why did the autonomous agent break up with its partner?
#
# Because they just couldn’t compute the chemistry!
